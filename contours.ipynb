# %%
import cv2
import matplotlib.pyplot as plt
import os

# %%
plt.rcParams['figure.figsize'] = [20, 15]

# %%
bgr = cv2.imread('teste.jpg')

imgray = cv2.cvtColor(bgr,cv2.COLOR_RGB2GRAY)
ret,thresh = cv2.threshold(imgray,127,255,0)
image, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# %%
i=1
for contour in contours:
    new_bgr = bgr.copy()
    (x, y, w, h) = cv2.boundingRect(contour)
    cv2.rectangle(new_bgr, (x,y), (x+w,y+h), (0,255,0),2)
    cv2.imwrite(os.getcwd() + '\\teste\\' + str(i) + '.jpg', new_bgr)
    i = i + 1

# %%
contour = contours[54]
(x,y,w,h) = cv2.boundingRect(contour)
print("x: " + str(x) + " y: " + str(y) + " w: " + str(w) + " h: " + str(h))
plt.imshow(bgr[y:y+h,x:x+w])
# Out:
# x: 1201 y: 1798 w: 964 h: 1745

# %%
width, height, _ = bgr.shape
min_x, min_y = width, height
max_x = max_y = 0

for contour in contours:
    (x,y,w,h) = cv2.boundingRect(contour)
    #print("x: " + str(x) + " y: " + str(y) + " w: " + str(w) + " h: " + str(h))
    if x != 0 and w != width:    
        min_x, max_x = min(x, min_x), max(x+w, max_x) 
        
    if y != 0 and h != height:
        min_y, max_y = min(y, min_y), max(y+h, max_y)
        
bgr = cv2.rectangle(bgr, (min_x, min_y), (max_x, max_y), (0,255,0),2)
