# %%
import cv2
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
img = cv2.imread('final.jpg')
plt.imshow(img)

# %%
h,w,__ = img.shape

# %%
first_row = img[0,:,0]
last_row = img[h-1,:,0]

top = np.where(first_row != 255)[0][0]
bot = np.where(last_row != 255)[0][-1]

m = top if top < bot else bot

# %%
new_img = np.full((h+500,w+500,3),255)
new_img[250:250+h,250:250+w,:] = img
n_h,n_w,__ = new_img.shape
m =

# %%
x_diff = n_w/2 - m
ang = math.atan(x_diff/n_h)*180

# %%
M = cv2.getRotationMatrix2D((n_w/2,n_h/2),ang,1)
dst = cv2.warpAffine(new_img,M,(n_w,n_h))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-185-93cbc1ff4256> in <module>()
#       1 M = cv2.getRotationMatrix2D((n_w/2,n_h/2),ang,1)
# ----> 2 dst = cv2.warpAffine(new_img,M,(n_w,n_h))
#
# error: OpenCV(3.4.2) C:\projects\opencv-python\opencv\modules\imgproc\src\imgwarp.cpp:1804: error: (-215:Assertion failed) ifunc != 0 in function 'cv::remap'

# %%
plt.imshow(dst)
