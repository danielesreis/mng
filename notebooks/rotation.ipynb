# %%
import cv2
import os 
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
img = cv2.imread(os.getcwd() + '\\..\\teste\\final.jpg')
plt.imshow(img)

# %%
h,w,__ = img.shape

# %%
first_row = img[0,:,0]
last_row = img[h-1,:,0]

top = np.where(first_row != 255)[0][0]
bot = np.where(last_row != 255)[0][-1]

m = abs(top - bot)
ang = math.tan(m/n_h)*180

# %%
new_img = np.full((h+500,w+500,3),255, dtype='uint8')
new_img[250:250+h,250:250+w,:] = img
n_h,n_w,__ = new_img.shape

# %%
M = cv2.getRotationMatrix2D((n_w/2,n_h/2),ang,1)
dst = cv2.warpAffine(new_img,M,(n_w,n_h))

# %%
plt.imshow(dst)
