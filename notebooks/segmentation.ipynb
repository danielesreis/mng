# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [30, 20]

# %%
ori = cv2.imread('/home/danielesreis/Downloads/agoravai.jpg')
img = cv2.cvtColor(ori, cv2.COLOR_BGR2GRAY)

# %%
cv2.imwrite('pb.jpg', img)
# Out:
# True

# %%
hist,bins = np.histogram(img.ravel(),256,[0,256])

# %%
plt.xlabel('Intensidades', fontsize=50)
plt.ylabel('Quantidade de pixels', fontsize=50)
n, bins, patches = plt.hist(img.ravel(), bins=np.arange(256), color='black')

# %%
plt.savefig('hist.jpg')

# %%
color_img = cv2.imread(os.getcwd() + '\\..\\teste\\final.jpg')

# %%
__, mask = cv2.threshold(img, 70, 255, cv2.THRESH_BINARY)
# mask = cv2.bitwise_not(mask)

# %%
thr_img = cv2.bitwise_and(ori, ori, mask=mask)

# %%
cv2.imwrite('thr_img.png', thr_img)
# Out:
# True

# %%
plt.imshow(thr_img)

# %%
cv2.imwrite('ue.jpg', thr_img)
# Out:
# True

# %%
grayscale_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)
__, mask 	= cv2.threshold(grayscale_img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
inv_mask	= cv2.bitwise_not(mask)
thr_img 	= cv2.bitwise_and(color_img, color_img, mask = inv_mask)
thr_img[thr_img == 0] = 255

# %%
plt.imshow(thr_img)

# %%
# testing bg preprocessing
bg = cv2.bitwise_and(color_img, color_img, mask = mask)
bg[bg!=0] = 255
plt.imshow(bg)

# %%
cv2.imwrite(os.getcwd() + '//segmented.jpg', thr_img)
# Out:
# True
